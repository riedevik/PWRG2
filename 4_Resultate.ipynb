# %% [markdown]
# # Resultate

# %% [markdown]
# ## Change Detection: potenzielle Abholzung zwischen 2021 und 2025
#
# Hier eine Karte mit Schieber: rechts RGB_clean aus 2021 und rechts RGB aus 2025 mit abgeholzten Pixel, Layer mit den Pixeln sollte man ausblenden können zur Kontrolle

# %% [markdown]
# ## Zeitreihenanalyse
